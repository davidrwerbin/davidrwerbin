# %% [markdown]
# ## ANIMAL DETECTOR

# %% [markdown]
# ![professor_jennifer_dogna_by_lowfire3_deg50t2-350t.jpg](data:image/jpeg;base64,...)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as imglib
import tensorflow as tf
from tensorflow import keras
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.metrics import plot_confusion_matrix #depreciated
from sklearn.svm import SVC
from sklearn import svm
from PIL import Image
import os

# %%
train_data = os.listdir("/content/drive/MyDrive/Animals")
train_data
# Out:
# ['cat', 'dog', 'fox']

# %%
X=[]
y=[]
for index,img_type in enumerate(train_data):
  print(img_type)
  p = os.path.join('/content/drive/MyDrive/Animals/', img_type+"/")
  list1 = os.listdir(p)
  for file1 in list1:
    #l_st = len(str(i))
    #st = '('+str(i)+')'
    #img = imglib.imread('/content/drive/MyDrive/Data/Car logo/'+img_type+st+'.jpg')
    #img = .open('/content/drive/MyDrive/Animals/'+img_type+"/"+ img_type +" "+ st+'.jpg')
    #img = img.convert('L') # turns color pictures to b&w
    #data=np.array(img.getdata())
    p2 = os.path.join(p, file1)
    img = imglib.imread(p2)
    X.append(img)
    y.append(index)
X = np.array(X)
y = np.array(y)
print(X.shape,y.shape)
# Out:
# cat
# dog
# fox
# (300, 512, 512, 3) (300,)

# %%
X = X / 255
X[0]
# Out:
# array([[[0.00133795, 0.00098424, 0.00086121],
#         [0.0014456 , 0.00109189, 0.00096886],
#         [0.00150711, 0.00116878, 0.00099962],
#         ...,
#         [0.00066128, 0.00046136, 0.00032295],
#         [0.00067666, 0.00052288, 0.00038447],
#         [0.00069204, 0.00055363, 0.00041522]],
#
#        [[0.00130719, 0.00095348, 0.00083045],
#         [0.00141484, 0.00106113, 0.0009381 ],
#         [0.00147636, 0.00113802, 0.00096886],
#         ...,
#         [0.0007228 , 0.00052288, 0.00038447],
#         [0.00067666, 0.00052288, 0.00038447],
#         [0.00064591, 0.0005075 , 0.00036909]],
#
#        [[0.00127643, 0.00092272, 0.00079969],
#         [0.00138408, 0.00104575, 0.00087659],
#         [0.00143022, 0.00109189, 0.00092272],
#         ...,
#         [0.00061515, 0.00041522, 0.0002922 ],
#         [0.00058439, 0.0004306 , 0.0002922 ],
#         [0.00056901, 0.00041522, 0.00027682]],
#
#        ...,
#
#        [[0.00058439, 0.0002153 , 0.00041522],
#         [0.00076894, 0.00044598, 0.00058439],
#         [0.00073818, 0.00041522, 0.00052288],
#         ...,
#         [0.00078431, 0.00076894, 0.00084583],
#         [0.00067666, 0.00066128, 0.00075356],
#         [0.00063053, 0.00064591, 0.0007228 ]],
#
#        [[0.00049212, 0.00012303, 0.00036909],
#         [0.00061515, 0.00024606, 0.00049212],
#         [0.00061515, 0.00024606, 0.00044598],
#         ...,
#         [0.00075356, 0.00073818, 0.00083045],
#         [0.0007228 , 0.0007228 , 0.00084583],
#         [0.00075356, 0.00075356, 0.00087659]],
#
#        [[0.00070742, 0.00032295, 0.00064591],
#         [0.00073818, 0.00035371, 0.00064591],
#         [0.00075356, 0.00038447, 0.00059977],
#         ...,
#         [0.00058439, 0.00056901, 0.00066128],
#         [0.00064591, 0.00064591, 0.00076894],
#         [0.00075356, 0.00075356, 0.00090734]]])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=41)
print("train: ", X_train.shape, y_train.shape)
print("test:  " , X_test.shape, y_test.shape)
# Out:
# train:  (240, 512, 512, 3) (240,)
# test:   (60, 512, 512, 3) (60,)

# %%
X[0].shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(X[0])

# %%
plt.figure(figsize=(15, 10))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.grid(False)
    plt.imshow(X[i+100])
plt.show()

# %%
sns.countplot(train_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(15, 10))
for i in range(20):
    plt.subplot(4, 5, i + 1)
    plt.grid(True)
    plt.imshow(X[i])
plt.show()

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(512, 512, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 510, 510, 64)      1792
#
#  max_pooling2d_4 (MaxPooling  (None, 255, 255, 64)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 253, 253, 64)      36928
#
#  max_pooling2d_5 (MaxPooling  (None, 126, 126, 64)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 124, 124, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 60, 60, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 57600)             0
#
#  dense_2 (Dense)             (None, 50)                2880050
#
#  dense_3 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 2,993,136
# Trainable params: 2,993,136
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100,validation_split=0.1)
print('\ncalculating test accuracy:')
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 380ms/step - loss: 1.1165 - accuracy: 0.3426 - val_loss: 1.1038 - val_accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 3s 364ms/step - loss: 1.1181 - accuracy: 0.2778 - val_loss: 1.1390 - val_accuracy: 0.2083
# Epoch 3/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1145 - accuracy: 0.3611 - val_loss: 1.1099 - val_accuracy: 0.2083
# Epoch 4/100
# 7/7 [==============================] - 3s 368ms/step - loss: 1.1122 - accuracy: 0.2963 - val_loss: 1.1041 - val_accuracy: 0.2917
# Epoch 5/100
# 7/7 [==============================] - 3s 368ms/step - loss: 1.1001 - accuracy: 0.3611 - val_loss: 1.1440 - val_accuracy: 0.2083
# Epoch 6/100
# 7/7 [==============================] - 3s 368ms/step - loss: 1.1069 - accuracy: 0.3611 - val_loss: 1.1519 - val_accuracy: 0.2083
# Epoch 7/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1007 - accuracy: 0.3009 - val_loss: 1.1007 - val_accuracy: 0.2083
# Epoch 8/100
# 7/7 [==============================] - 3s 370ms/step - loss: 1.1048 - accuracy: 0.3611 - val_loss: 1.1169 - val_accuracy: 0.2083
# Epoch 9/100
# 7/7 [==============================] - 3s 366ms/step - loss: 1.1119 - accuracy: 0.3611 - val_loss: 1.1218 - val_accuracy: 0.2083
# Epoch 10/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1147 - accuracy: 0.3009 - val_loss: 1.0839 - val_accuracy: 0.5000
# Epoch 11/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1030 - accuracy: 0.3426 - val_loss: 1.1545 - val_accuracy: 0.2083
# Epoch 12/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1067 - accuracy: 0.3611 - val_loss: 1.1200 - val_accuracy: 0.2083
# Epoch 13/100
# 7/7 [==============================] - 3s 366ms/step - loss: 1.1030 - accuracy: 0.3611 - val_loss: 1.1105 - val_accuracy: 0.2083
# Epoch 14/100
# 7/7 [==============================] - 3s 370ms/step - loss: 1.1023 - accuracy: 0.2731 - val_loss: 1.1306 - val_accuracy: 0.2083
# Epoch 15/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1061 - accuracy: 0.3611 - val_loss: 1.1117 - val_accuracy: 0.2083
# Epoch 16/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1053 - accuracy: 0.3241 - val_loss: 1.1519 - val_accuracy: 0.2083
# Epoch 17/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1032 - accuracy: 0.3333 - val_loss: 1.1006 - val_accuracy: 0.2083
# Epoch 18/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1169 - accuracy: 0.3611 - val_loss: 1.1635 - val_accuracy: 0.2083
# Epoch 19/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1046 - accuracy: 0.3102 - val_loss: 1.0868 - val_accuracy: 0.5000
# Epoch 20/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1041 - accuracy: 0.3287 - val_loss: 1.1280 - val_accuracy: 0.2083
# Epoch 21/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1051 - accuracy: 0.3611 - val_loss: 1.1287 - val_accuracy: 0.2083
# Epoch 22/100
# 7/7 [==============================] - 3s 370ms/step - loss: 1.1061 - accuracy: 0.3102 - val_loss: 1.0912 - val_accuracy: 0.5000
# Epoch 23/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1185 - accuracy: 0.3241 - val_loss: 1.1709 - val_accuracy: 0.2083
# Epoch 24/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.0960 - accuracy: 0.3611 - val_loss: 1.0919 - val_accuracy: 0.5000
# Epoch 25/100
# 7/7 [==============================] - 3s 368ms/step - loss: 1.1093 - accuracy: 0.3148 - val_loss: 1.0902 - val_accuracy: 0.5000
# Epoch 26/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1165 - accuracy: 0.3056 - val_loss: 1.1726 - val_accuracy: 0.2083
# Epoch 27/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.1081 - accuracy: 0.3426 - val_loss: 1.0808 - val_accuracy: 0.5000
# Epoch 28/100
# 7/7 [==============================] - 3s 368ms/step - loss: 1.1026 - accuracy: 0.3102 - val_loss: 1.1246 - val_accuracy: 0.2917
# Epoch 29/100
# 7/7 [==============================] - 3s 367ms/step - loss: 1.1061 - accuracy: 0.3102 - val_loss: 1.1317 - val_accuracy: 0.2083
# Epoch 30/100
# 7/7 [==============================] - 3s 369ms/step - loss: 1.1024 - accuracy: 0.3472 - val_loss: 1.0965 - val_accuracy: 0.4167
# Epoch 31/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.0564 - accuracy: 0.5370 - val_loss: 1.0061 - val_accuracy: 0.5000
# Epoch 32/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.8954 - accuracy: 0.6296 - val_loss: 1.1944 - val_accuracy: 0.3333
# Epoch 33/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.7378 - accuracy: 0.6620 - val_loss: 0.8013 - val_accuracy: 0.5833
# Epoch 34/100
# 7/7 [==============================] - 3s 367ms/step - loss: 0.7615 - accuracy: 0.6389 - val_loss: 1.1079 - val_accuracy: 0.5833
# Epoch 35/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.5964 - accuracy: 0.7454 - val_loss: 0.7836 - val_accuracy: 0.7500
# Epoch 36/100
# 7/7 [==============================] - 3s 371ms/step - loss: 0.4438 - accuracy: 0.8519 - val_loss: 0.8203 - val_accuracy: 0.8333
# Epoch 37/100
# 7/7 [==============================] - 3s 369ms/step - loss: 0.3729 - accuracy: 0.8611 - val_loss: 1.1608 - val_accuracy: 0.7917
# Epoch 38/100
# 7/7 [==============================] - 3s 371ms/step - loss: 0.2888 - accuracy: 0.8750 - val_loss: 0.8890 - val_accuracy: 0.8750
# Epoch 39/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.2049 - accuracy: 0.9306 - val_loss: 1.0585 - val_accuracy: 0.7917
# Epoch 40/100
# 7/7 [==============================] - 3s 368ms/step - loss: 0.1885 - accuracy: 0.9352 - val_loss: 1.1532 - val_accuracy: 0.7917
# Epoch 41/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.1034 - accuracy: 0.9676 - val_loss: 1.5541 - val_accuracy: 0.7500
# Epoch 42/100
# 7/7 [==============================] - 3s 372ms/step - loss: 0.1439 - accuracy: 0.9398 - val_loss: 1.4865 - val_accuracy: 0.7917
# Epoch 43/100
# 7/7 [==============================] - 3s 371ms/step - loss: 0.0733 - accuracy: 0.9815 - val_loss: 2.2000 - val_accuracy: 0.8333
# Epoch 44/100
# 7/7 [==============================] - 3s 372ms/step - loss: 0.0856 - accuracy: 0.9815 - val_loss: 1.1792 - val_accuracy: 0.8333
# Epoch 45/100
# 7/7 [==============================] - 3s 369ms/step - loss: 0.0349 - accuracy: 0.9954 - val_loss: 1.8610 - val_accuracy: 0.8333
# Epoch 46/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.0325 - accuracy: 0.9954 - val_loss: 2.8353 - val_accuracy: 0.7083
# Epoch 47/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.1242 - accuracy: 0.9583 - val_loss: 2.0367 - val_accuracy: 0.8333
# Epoch 48/100
# 7/7 [==============================] - 3s 373ms/step - loss: 0.0666 - accuracy: 0.9769 - val_loss: 1.4036 - val_accuracy: 0.7917
# Epoch 49/100
# 7/7 [==============================] - 3s 373ms/step - loss: 0.0671 - accuracy: 0.9769 - val_loss: 1.9176 - val_accuracy: 0.7500
# Epoch 50/100
# 7/7 [==============================] - 3s 375ms/step - loss: 0.0795 - accuracy: 0.9769 - val_loss: 1.1868 - val_accuracy: 0.8750
# Epoch 51/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.0339 - accuracy: 0.9907 - val_loss: 1.5566 - val_accuracy: 0.7917
# Epoch 52/100
# 7/7 [==============================] - 3s 371ms/step - loss: 0.0224 - accuracy: 0.9954 - val_loss: 2.3614 - val_accuracy: 0.7917
# Epoch 53/100
# 7/7 [==============================] - 3s 373ms/step - loss: 0.0290 - accuracy: 0.9907 - val_loss: 1.4058 - val_accuracy: 0.8750
# Epoch 54/100
# 7/7 [==============================] - 3s 372ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 2.1366 - val_accuracy: 0.7917
# Epoch 55/100
# 7/7 [==============================] - 3s 370ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.7704 - val_accuracy: 0.8333
# Epoch 56/100
# 7/7 [==============================] - 3s 372ms/step - loss: 0.0112 - accuracy: 0.9954 - val_loss: 2.1540 - val_accuracy: 0.7917
# Epoch 57/100
# 7/7 [==============================] - 3s 373ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.1971 - val_accuracy: 0.8333
# Epoch 58/100
# 7/7 [==============================] - 3s 371ms/step - loss: 5.5071e-04 - accuracy: 1.0000 - val_loss: 2.2451 - val_accuracy: 0.8333
# Epoch 59/100
# 7/7 [==============================] - 3s 376ms/step - loss: 6.4737e-04 - accuracy: 1.0000 - val_loss: 2.2835 - val_accuracy: 0.8333
# Epoch 60/100
# 7/7 [==============================] - 3s 372ms/step - loss: 6.9503e-04 - accuracy: 1.0000 - val_loss: 2.2795 - val_accuracy: 0.8333
# Epoch 61/100
# 7/7 [==============================] - 3s 374ms/step - loss: 5.1462e-04 - accuracy: 1.0000 - val_loss: 2.2953 - val_accuracy: 0.8333
# Epoch 62/100
# 7/7 [==============================] - 3s 373ms/step - loss: 3.9914e-04 - accuracy: 1.0000 - val_loss: 2.3192 - val_accuracy: 0.8333
# Epoch 63/100
# 7/7 [==============================] - 3s 373ms/step - loss: 3.2840e-04 - accuracy: 1.0000 - val_loss: 2.3486 - val_accuracy: 0.8333
# Epoch 64/100
# 7/7 [==============================] - 3s 372ms/step - loss: 2.9313e-04 - accuracy: 1.0000 - val_loss: 2.3766 - val_accuracy: 0.8333
# Epoch 65/100
# 7/7 [==============================] - 3s 373ms/step - loss: 2.6891e-04 - accuracy: 1.0000 - val_loss: 2.4016 - val_accuracy: 0.8333
# Epoch 66/100
# 7/7 [==============================] - 3s 373ms/step - loss: 2.5249e-04 - accuracy: 1.0000 - val_loss: 2.4243 - val_accuracy: 0.8333
# Epoch 67/100
# 7/7 [==============================] - 3s 371ms/step - loss: 2.3732e-04 - accuracy: 1.0000 - val_loss: 2.4404 - val_accuracy: 0.8333
# Epoch 68/100
# 7/7 [==============================] - 3s 373ms/step - loss: 2.2639e-04 - accuracy: 1.0000 - val_loss: 2.4564 - val_accuracy: 0.8333
# Epoch 69/100
# 7/7 [==============================] - 3s 373ms/step - loss: 2.1379e-04 - accuracy: 1.0000 - val_loss: 2.4663 - val_accuracy: 0.8333
# Epoch 70/100
# 7/7 [==============================] - 3s 373ms/step - loss: 2.0613e-04 - accuracy: 1.0000 - val_loss: 2.4788 - val_accuracy: 0.8333
# Epoch 71/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.9653e-04 - accuracy: 1.0000 - val_loss: 2.4857 - val_accuracy: 0.8333
# Epoch 72/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.8888e-04 - accuracy: 1.0000 - val_loss: 2.4944 - val_accuracy: 0.8333
# Epoch 73/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.8145e-04 - accuracy: 1.0000 - val_loss: 2.5025 - val_accuracy: 0.8333
# Epoch 74/100
# 7/7 [==============================] - 3s 377ms/step - loss: 1.7535e-04 - accuracy: 1.0000 - val_loss: 2.5090 - val_accuracy: 0.8333
# Epoch 75/100
# 7/7 [==============================] - 3s 372ms/step - loss: 1.6990e-04 - accuracy: 1.0000 - val_loss: 2.5168 - val_accuracy: 0.8333
# Epoch 76/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.6362e-04 - accuracy: 1.0000 - val_loss: 2.5245 - val_accuracy: 0.8333
# Epoch 77/100
# 7/7 [==============================] - 3s 372ms/step - loss: 1.5903e-04 - accuracy: 1.0000 - val_loss: 2.5315 - val_accuracy: 0.8333
# Epoch 78/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.5426e-04 - accuracy: 1.0000 - val_loss: 2.5372 - val_accuracy: 0.8333
# Epoch 79/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.4970e-04 - accuracy: 1.0000 - val_loss: 2.5469 - val_accuracy: 0.8333
# Epoch 80/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.4525e-04 - accuracy: 1.0000 - val_loss: 2.5574 - val_accuracy: 0.8333
# Epoch 81/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.4144e-04 - accuracy: 1.0000 - val_loss: 2.5637 - val_accuracy: 0.8333
# Epoch 82/100
# 7/7 [==============================] - 3s 375ms/step - loss: 1.3731e-04 - accuracy: 1.0000 - val_loss: 2.5707 - val_accuracy: 0.8333
# Epoch 83/100
# 7/7 [==============================] - 3s 375ms/step - loss: 1.3353e-04 - accuracy: 1.0000 - val_loss: 2.5774 - val_accuracy: 0.8333
# Epoch 84/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.3005e-04 - accuracy: 1.0000 - val_loss: 2.5838 - val_accuracy: 0.8333
# Epoch 85/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.2707e-04 - accuracy: 1.0000 - val_loss: 2.5888 - val_accuracy: 0.8333
# Epoch 86/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.2337e-04 - accuracy: 1.0000 - val_loss: 2.5953 - val_accuracy: 0.8333
# Epoch 87/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.2066e-04 - accuracy: 1.0000 - val_loss: 2.6009 - val_accuracy: 0.8333
# Epoch 88/100
# 7/7 [==============================] - 3s 373ms/step - loss: 1.1773e-04 - accuracy: 1.0000 - val_loss: 2.6071 - val_accuracy: 0.8333
# Epoch 89/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.1493e-04 - accuracy: 1.0000 - val_loss: 2.6158 - val_accuracy: 0.8333
# Epoch 90/100
# 7/7 [==============================] - 3s 375ms/step - loss: 1.1216e-04 - accuracy: 1.0000 - val_loss: 2.6220 - val_accuracy: 0.8333
# Epoch 91/100
# 7/7 [==============================] - 3s 376ms/step - loss: 1.0967e-04 - accuracy: 1.0000 - val_loss: 2.6280 - val_accuracy: 0.8333
# Epoch 92/100
# 7/7 [==============================] - 3s 375ms/step - loss: 1.0734e-04 - accuracy: 1.0000 - val_loss: 2.6361 - val_accuracy: 0.8333
# Epoch 93/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.0493e-04 - accuracy: 1.0000 - val_loss: 2.6436 - val_accuracy: 0.8333
# Epoch 94/100
# 7/7 [==============================] - 3s 374ms/step - loss: 1.0268e-04 - accuracy: 1.0000 - val_loss: 2.6481 - val_accuracy: 0.8333
# Epoch 95/100
# 7/7 [==============================] - 3s 371ms/step - loss: 1.0024e-04 - accuracy: 1.0000 - val_loss: 2.6550 - val_accuracy: 0.8333
# Epoch 96/100
# 7/7 [==============================] - 3s 372ms/step - loss: 9.8294e-05 - accuracy: 1.0000 - val_loss: 2.6621 - val_accuracy: 0.8333
# Epoch 97/100
# 7/7 [==============================] - 3s 374ms/step - loss: 9.6295e-05 - accuracy: 1.0000 - val_loss: 2.6658 - val_accuracy: 0.8333
# Epoch 98/100
# 7/7 [==============================] - 3s 373ms/step - loss: 9.4213e-05 - accuracy: 1.0000 - val_loss: 2.6713 - val_accuracy: 0.8333
# Epoch 99/100
# 7/7 [==============================] - 3s 371ms/step - loss: 9.2435e-05 - accuracy: 1.0000 - val_loss: 2.6793 - val_accuracy: 0.8333
# Epoch 100/100
# 7/7 [==============================] - 3s 371ms/step - loss: 9.0324e-05 - accuracy: 1.0000 - val_loss: 2.6841 - val_accuracy: 0.8333
#
# calculating test accuracy:

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 2/2 [==============================] - 0s 149ms/step - loss: 1.2275 - accuracy: 0.8667
